# %% [markdown]
# <a href="https://colab.research.google.com/github/SagarSinghThapa/Python/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# write a program to create tfollowing dataset using numpy and pandas
#
# ---

# %%
import numpy as np
import pandas as pd
import seaborn as sb

# df=pd.DataFrame(data=np.arange(0,70).reshape(10,7))
# print(df)

l1=['500124495','Sagar', 'Singh Thapa', "Python",'80']
l2=['500124495','Mono', 'Bisht', "C++",'77']
l3=['50012400','Akarsh', 'Shukla', "Java",'75']
df=pd.DataFrame(data=np.array([l1,l2,l3]),index=[i for i in range(1,4)],columns=['Student_ID','First_Name','Last_Name','Skills','Marks'])
# df.head()
df.describe()
# a2=np.array([l1,l2,l3])
# print(a2)

# a2[2]='Mayank'
# print(a2)
# Out:
#        Student_ID First_Name    Last_Name  Skills Marks
# count           3          3            3       3     3
# unique          2          3            3       3     3
# top     500124495      Sagar  Singh Thapa  Python    80
# freq            2          1            1       1     1
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_16.groupby('Student_ID').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_17.groupby('First_Name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...
